# %%
import numpy as np
import pylab as pl
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import utils, regularizers, callbacks, backend
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout, Add, LSTM, Embedding
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from astropy.io import fits
from IPython.display import YouTubeVideo
from tools.resample_flux import trapz_rebin
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # <span style="color:#3E2D80">Creando un cerebro artifical para encontrar la más temperamental de las bestias astronómicas</span>

# %% [markdown]
# Si crees que Nueva York es un lugar ajetreado, ¡piénsalo de nuevo! El espacio está lleno de cosas que chocan continuamente en la noche. Durante su estudio de cinco años, DESI tendrá la oportunidad de atrapar a miles de las bestias astronómicas más temperamentales del Universo, desde [estrellas en explosión](https://es.wikipedia.org/wiki/Supernova) a [estrellas de neutrones fusionandose con agujeros negros](https://es.wikipedia.org/wiki/Kilonova) y [estrellas destrozadas por agujeros negros](https://es.wikipedia.org/wiki/Evento_de_disrupci%C3%B3n_de_marea), sin mencionar una larga lista de otros eventos fantásticos.

# %% [markdown]
# Los científicos de DESI son inteligentes, ¡pero ni siquiera ellos pueden identificar todos estos casi > 30 millones de espectros! Afortunadamente, tenemos expertos que saben cómo crear cerebros artificiales, o redes neuronales, construidas para especializarse en tareas como esta. En este cuaderno, [Segev Ben Zvi](https://www.pas.rochester.edu/~sybenzvi/),

# %% [markdown]
# <img src="../desihigh/images/Segev.jpg" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# nos pondrá al día con el aprendizaje automático de vanguardia y cómo se usa en esta búsqueda. Las supernovas (de tipo Ia) son las más críticas para la cosmología, así que primero nos centraremos en cómo identificarlas (a simple vista), ¡luego enseñaremos a bits de silicio a hacerlo!

# %% [markdown]
# ### Supernovas de colapso del núcleo
#
# En casi todos los casos, las supernovas son la etapa final del ciclo de vida de las estrellas más masivas (> 10 $ M_{\odot} $, 10 veces mayor que la masa del Sol). Finalmente, el combustible disponible que sostiene la fusión nuclear en el núcleo se agota y la energía utilizada para soportar la capa más externa desaparece. Entonces, inevitablemente, la estrella colapsa por su propio peso en una violenta explosión que dura solo una fracción de segundo. Quedará una estrella de neutrones o, si la estrella progenitora es lo suficientemente masiva, incluso un [agujero negro](https://es.wikipedia.org/wiki/Agujero_negro).

# %%
YouTubeVideo('o-Psuz7u5OI', width=800, height=400)

# %% [markdown]
# ### Supernovas binarias
#
# No todas las supernovas surgen debido al colapso del núcleo. En sistemas binarios con una enana blanca compacta y una estrella envejecida (secuencia principal), la enana blanca puede atraer material gravitacionalmente desde la superficie de su compañera. Si se acumula suficiente material en la superficie de la enana blanca para que su masa total exceda el [límite de Chandrasekhar](https://es.wikipedia.org/wiki/L%C3%ADmite_de_Chandrasekhar), 1.44 $ M_\odot $, entonces ocurre una reacción nuclear descontrolada que hace explotar la Enana Blanca en una explosión intensamente brillante. ¡Estas llamadas supernovas de tipo Ia son la razón por la que descubrimos la Energía Oscura en primer lugar!

# %% [markdown]
# <img src="../desihigh/images/type1a.jpg" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# Estos diferentes tipos de supernova se distinguen por su brillo cambiante con el tiempo, su _'curva de luz'_, pero si tenemos el espectro de la supernova, es mucho menos probable que cometamos un error. Cada espectro de supernova tiene líneas muy amplias distintas tanto en emisión como en absorción (Si II, H $\alpha$, Ca II, etc.), del gas caliente que escapa de la explosión central a alta velocidad. Estas "huellas" permiten distinguir los distintos tipos.

# %% [markdown]
# <img src="../desihigh/images/sne_filippenko.png" width="600px"/>

# %% [markdown]
# ¿Puedes decir qué es diferente entre estos cuatro ejemplos? ¿Tienen líneas en común y diferencias? Durante muchas décadas, los astrónomos han seguido esta lógica y la han dividido en una clasificación de supernovas, lo que nos dice el mecanismo detrás de su origen.

# %% [markdown]
# <img src="../desihigh/images/SupernovaeClassification.png" width="600px"/>

# %% [markdown]
# Por ejemplo, una supernovas de tipo Ib no muestra líneas de hidrógeno (H), pero sí las de helio.

# %% [markdown]
# ##  Cátalogo de Galaxias Brillantes de DESI (Bright Galaxy Survey)

# %% [markdown]
# Para ser lo suficientemente brillantes como para ser detectadas, las supernovas deben vivir en una galaxia relativamente cercana, como Messier 101,

# %% [markdown]
# <img src="../desihigh/images/type1aBGS.jpg" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# Con su estudio de diez millones de galaxias en el Universo _local_, el DESI Bright Galaxy Survey será perfecto para encontrarlas, ya que la luz recolectada por cualquier fibra dada será el total de la galaxia y la luz de una supernova potencial,

# %% [markdown]
# <img src="../desihigh/images/Messier101.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# donde vemos la misma galaxia Messier 101 en las imágenes Legacy de DESI y el área sobre la cual la luz es recolectada por las fibras (círculos). No sabremos de antemano si hay supernovas allí, por supuesto, así que esto solo funciona ya que DESI observará muchas galaxias y la tasa de supernovas en el Universo es relativamente alta, ¡así que tenemos buenas probabilidades!

# %% [markdown]
# Veamos cómo se ve esto en la práctica.

# %% [markdown]
# ###  ¿Qué ve DESI?

# %%
# Abrimos el archivo y vemos su contenido básico
hdus = fits.open('../desihigh/dat/bgs-supernovae.fits')
hdus.info()
# Out:
# Filename: ../desihigh/dat/bgs-supernovae.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  WAVE          1 PrimaryHDU       8   (6265,)   float64
#   1  FLUX          1 ImageHDU         8   (6265, 6)   float64
#   2  IVAR          1 ImageHDU         8   (6265, 6)   float64
#   3  MASK          1 ImageHDU        10   (6265, 6)   int32 (rescales to uint32)
#   4  SPECTYPE      1 BinTableHDU     11   6R x 1C   [10A]

# %% [markdown]
# Aquí _WAVE_ es simplemente un arreglo que nos da las longitudes de onda a las que se observa la luz,

# %%
hdus['WAVE'].data
# Out:
# array([3569.60009766, 3570.60009766, 3571.60009766, ..., 9831.59960938,
#        9832.59960938, 9833.59960938])

# %% [markdown]
# _FLUX_ es la intensidad de luz observada y _IVAR_ es $ (1\ / \ \rm{varianza \ esperada }) $ del flujo, es decir, de esto podemos derivar el error en este flujo observado. ¿Puedes pensar cómo? Dada la forma,

# %%
hdus['FLUX'].data.shape
# Out:
# (6, 6265)

# %% [markdown]
# de los datos (aquí una _matriz_ o cuadrícula de números, cada uno se conoce como un _elemento_) vemos que tenemos el flujo o la intensidad de la luz medida en las mismas longitudes de onda anteriores de seis galaxias diferentes. Para ser explícitos,

# %%
plt.imshow(hdus['FLUX'].data, aspect='auto')

pl.xlabel('Wavelength element')
pl.ylabel('Galaxy index')
# Out:
# Text(0, 0.5, 'Galaxy index')

# %% [markdown]
# Aquí, amarillo indica dónde el flujo es grande y azul dónde es pequeño. Esto queda más claro si tomamos un espectro a la vez:

# %%
# Graficamos todos los espectros en la misma cuadrícula de longitud de onda.
fig, axes = plt.subplots(2,3, figsize=(8,5), sharex=True, sharey=True, tight_layout=True)

for i, ax in enumerate(axes.flatten()):
    wave = hdus['WAVE'].data
    flux = hdus['FLUX'].data[i]
    ivar = hdus['IVAR'].data[i]
    spec = hdus['SPECTYPE'].data[i][0]
    
    ax.plot(wave, flux, alpha=0.5)
    ax.set(xlim=(3600, 9800), ylim=(-10,50),
           title=spec)

axes[0,0].set(ylabel=r'Flux [$10^{-17}$ erg cm$^{-2}$ s$^{-1}$ $\AA^{-1}$]');
axes[1,0].set(ylabel=r'Flux [$10^{-17}$ erg cm$^{-2}$ s$^{-1}$ $\AA^{-1}$]');

for i in range(0,3):
    axes[1,i].set(xlabel=r'Longitud de onda observada [$\AA$]')

# %% [markdown]
# Estos son los flujos observados por una fibra determinada de DESI, después de haber removido la luz conocida de la atmósfera. En la parte superior izquierda, tenemos la luz emitida por una galaxia BGS típica. Los otros paneles contienen la luz de la galaxia de un tipo específico de supernovas en cada caso. ¡Lo primero que hay que notar es que esto es _mucho_ menos claro de lo que esperábamos del espectro de ejemplo anterior!
#
# Entonces, ¿cómo podemos confirmar que la luz de las supernovas de cada tipo (Ib, Ic, IIn, IIP) está realmente allí?

# %% [markdown]
# ## Menos es más

# %% [markdown]
# Nuestro "problema" es que DESI mide la cantidad de luz en intervalos muy pequeños en longitud de onda (o color), debido a su alta resolución. Los espectros de objetivos específicos, en este caso supernovas, pueden no cambiar mucho en un intervalo de longitud de onda pequeño, por lo que terminamos con muchas mediciones _ruidosas_ de la misma cosa: la intensidad de la luz en un color o longitud de onda promedio.
#
# Esto es _genial_, ya que podemos ser inteligentes y simplemente combinar estas medidas para obtener un valor promedio que es mucho más _preciso_.

# %%
# Graficamos todos los espectros en la misma cuadrícula de longitud de onda.
fig, axes = plt.subplots(2,3, figsize=(15,8), sharex=True, sharey=True, tight_layout=True)

# Remuestreamos el flujo en una nueva cuadrícula de longitud de onda con solo 100 bins.
coarse_wave = np.linspace(3600, 9800, 101)

for i, ax in enumerate(axes.flatten()):
    wave = hdus['WAVE'].data
    flux = hdus['FLUX'].data[i]
    ivar = hdus['IVAR'].data[i]
    spec = hdus['SPECTYPE'].data[i][0]
    
    ax.plot(wave, flux, alpha=0.5)
        
    fl   = trapz_rebin(wave, flux, edges=coarse_wave)
    
    ax.plot(coarse_wave[:-1], fl, 'k-', alpha=0.2)
    
    ax.set(xlim=(3600, 9800), ylim=(-10,50),
           title=spec)

axes[0,0].set(ylabel=r'flux [$10^{-17}$ erg cm$^{-2}$ s$^{-1}$ $\AA^{-1}$]');
axes[1,0].set(ylabel=r'flux [$10^{-17}$ erg cm$^{-2}$ s$^{-1}$ $\AA^{-1}$]');

for i in range(0,3):
    axes[1,i].set(xlabel=r'Observed wavelength [$\AA$]')

# %% [markdown]
# ¡Y ahora vemos mucho mejor los deeps característicos, o líneas de absorción, de las supernovas! Por supuesto, este no es el único enfoque. Podríamos haber usado estadística y los datos originales 'no agrupados', pero las cosas siempre son mejores cuando son más transparentes. Sin embargo, sigue siendo complicado, ya que la velocidad de la estrella significa que las líneas de absorción no estarán donde las esperaríamos normalmente. En este sentido, hay _dos corrimientos al rojo_ en el espectro.

# %% [markdown]
# Así que hemos identificado con éxito una supernova de DESI (simulada, ¡por ahora!), pero no podríamos inspeccionar visualmente el catálogo completo de esta manera. Necesitamos un método más eficiente...

# %% [markdown]
# ## Un cerebro artificial: donde la anatomía se encuentra con la astronomía

# %% [markdown]
# <img src="../desihigh/images/AIBrain.jpg" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# Dada la increíble capacidad del cerebro humano, ¿a quién no se le ocurriría intentar comprenderlo y reproducirlo? Se logró un gran progreso en la década de 1940 con modelos simples que llevaron a los modelos de vanguardia de _aprendizaje profundo_ que han sido fundamentales para Google, Amazon y otras tecnologías hoy en día gigantes.

# %% [markdown]
# En las neuronas biológicas, las dendritas reciben señales de entrada de _miles_ de neuronas vecinas. Estas señales se _combinan_ en el núcleo y pasan a un axón. Solo si la señal combinada es _mayor que un valor de umbral_, entonces el axón liberará una señal prescrita. De lo contrario, no se propaga ninguna señal. En este sentido, es probable que tu dinero también esté sujeto a un umbral similar: sólo te pagarán si haces la cantidad de tareas requeridas, si lo intentas un poco pero te rindes es probable que no recibas nada.

# %% [markdown]
# <img src="../desihigh/images/Dendrite.jpg" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# Este simple paso final es donde ocurre la magia. Antes de esto, la señal de salida es una simple suma ponderada de las señales de entrada, p. Ej. $ y = a \cdot x + b $. Las posibilidades de esta configuración son relativamente limitadas.
#
# El umbral hace que la señal sea _no lineal_, de modo que cuando la señal de entrada cambia en una _cantidad pequeña, dx_, la señal de salida puede cambiar _mucho_. Esto, junto con el _gran número_ de neuronas (relativamente simples) en el cerebro permite un potencial casi ilimitado, representado por el rango de posibilidades de salida o ideas que pueden formarse. Mientras lees esto, hay _100 mil millones_ de neuronas que pueden disparar su imaginación. ¡Quién sabe lo que se te ocurra!

# %% [markdown]
# ### Potencial ilimitado

# %% [markdown]
# El aprendizaje automático 'profundo' es donde estas ideas relativamente simples se encuentran con la potencia informática bruta que nos otorgó [John von Neumann](https://es.wikipedia.org/wiki/John_von_Neumann), [John Bardeen](https://es.wikipedia.org/wiki/John_Bardeen), ... Las cosas realmente despegaron cuando salió a la luz el [martillo](https://es.wikipedia.org/wiki/Unidad_de_procesamiento_gr%C3%A1fico) adecuado para el problema.

# %% [markdown]
# En una computadora podemos tener una serie de valores de entrada, $ x_1, x_2, ... $, como lo que sería recolectado por las dendritas, que se ponderan y suman, $ a_1 \cdot x_1 + a_2 \cdot x_2 + ... + b_1+ ... $ como en el axón. Aquí $a_1, a_2$ representan los pesos y $b_1$ el sesgo (bias en inglés) -- un simple número independiente de los valores de entrada. Esto puede suceder varias veces, en una serie de 'capas ocultas', donde la salida de la capa anterior actúa como entrada de la siguiente. En cualquier etapa, aunque normalmente es la última, la "_magia_" podría ser introducida, o de forma similar, en una capa determinada. Por lo general, esto se conoce como "activación", en analogía con el disparo de un axón.

# %% [markdown]
# <img src="../desihigh/images/network.jpg" width="600px"/>

# %% [markdown]
# De antemano, o _a priori_, no tenemos idea de cuál debería ser el peso de nuestra 'red neuronal' artificial para un problema dado. La capacidad de la configuración está representada por el número de salidas diferentes que se pueden generar cuando cualquier peso determinado produce un nuevo número aleatorio, el resultado de lo que normalmente será algo sin sentido para una entrada dada.

# %% [markdown]
# Pero si podemos definir el "éxito", como la satisfacción después de una buena comida o una broma, entonces podemos inculcar el "buen comportamiento" en los pesos. Introducimos repetidamente la red en un rango de escenarios diferentes y permitimos que los pesos, $ a_1, ..., b_1, ... $, o entidad, se refinen a aquellos que logran el _mayor éxito_, según se define en comparación con la 'verdad'. De esta manera, podemos replicar cientos de generaciones de [selección natural](https://es.wikipedia.org/wiki/Selecci%C3%B3n_natural) en una fracción de segundo.

# %% [markdown]
# ### Si la vida fuera tan simple

# %% [markdown]
# El atractivo del aprendizaje profundo es claro, al igual que su potencial: ¿cuántas veces te has equivocado en tu vida? Claro, siempre estamos aprendiendo, pero la ciencia generalmente se basa en lo que sabemos y lo que no, dentro de lo razonable. No sobrevivirás demasiado tiempo en el campo si predices una respuesta diferente a la que tenías seis meses antes, ¡a pesar de lo mucho que hayas aprendido!
#
# En otras palabras, lo más importante es saber lo que puedes decir _con confianza_. Normalmente, las redes neuronales harán una predicción definitiva, sin tener idea de su confianza y crecimiento potencial. Como tal, podríamos revisar nuestra ambición ...

# %% [markdown]
# ### Potencial Limitado

# %% [markdown]
# Habiendo admitido nuestro potencial mundano, podríamos sacrificar algo de nuestra capacidad de ser perfectos, a favor de limitar el _potencial de equivocarnos_. Esto puede ser práctico, ya que una red con una gran cantidad de pesos puede ser infalible dada una potencia informática infinita, pero de lo contrario sería un desafío enorme.

# %% [markdown]
# Uno de los medios más efectivos para limitar el número de pesos en nuestra red y, por lo tanto, la posibilidad de estar equivocados, es reemplazar capas ocultas 'completamente conectadas' de pesos arbitrarios con capas 'convolucionales'. Una convolución simplemente reemplaza una cantidad de píxeles vecinos con un promedio ponderado, como en este caso.

# %% [markdown]
# <img src="../desihigh/images/CMB-lensing.jpg" width="600px"/>

# %% [markdown]
# Así, no es algo muy diferente a una capa completamente conectada. Sin embargo, difiere en que los pesos aplicados dentro de la imagen son _constantes en toda la imagen_. En otras palabras, una capa "completamente conectada" permite un tamaño, forma y tipo de vaso diferentes en cualquier posición dada de una imagen. Al restringirnos a 'un vaso', reducimos en gran medida el potencial de la red, tanto en su capacidad para tener razón como para estar equivocado.
#
# De esta manera, hemos recurrido a [filtros adaptados](https://es.wikipedia.org/wiki/Filtro_adaptado) arbitrarios, conocidos desde la invención del radar y el sonar. Eso no quiere decir que no tengamos algunas capas completamente conectadas, que podrían detectar anomalías que no son consistentes en una imagen determinada.

# %% [markdown]
# ## El Evento Principal

# %% [markdown]
# Primero, simplemente abramos nuestro archivo de datos y hagamos un listado del resultado.

# %%
spectra = np.load('../desihigh/dat/sn_simspectra.npz')
spectra.files
# Out:
# ['wave', 'hosts', 'snia', 'snib', 'snic', 'sniip']

# %% [markdown]
# y descomprimámoslo en algo más explícito,

# %%
wave        = spectra['wave']

# Host galaxy.
host_fluxes = spectra['hosts']

snia_fluxes = spectra['snia']
snib_fluxes = spectra['snib']
snic_fluxes = spectra['snic']
snii_fluxes = spectra['sniip']

# %% [markdown]
# Como anteriormente, esto es simplemente espectros de galaxias (hospedaje de nuestras supernovas) de ejemplo, junto con ejemplos que contienen clases específicas de supernovas. Para ser concretos, tracemos un espectro de cada uno.

# %%
fig, axes = plt.subplots(2,3, figsize = (12,7), tight_layout=True, sharex=True, sharey=True)

ax = axes[0,0]
ax.plot(wave, host_fluxes[0])
ax.set(ylabel='normalized flux',
       title='BGS host galaxy')

ax = axes[0,1]
ax.plot(wave, snia_fluxes[0])
ax.set(title='Host + SN Ia')

ax = axes[0,2]
ax.plot(wave, snib_fluxes[0])
ax.set(title='Host + SN Ib')

ax = axes[1,0]
ax.plot(wave, snic_fluxes[0])
ax.set(xlabel=r'Rest frame wavelength [$\AA$]',
       ylabel='Normalized flux',
       title='Host + SN Ic')

ax = axes[1,1]
ax.plot(wave, snii_fluxes[0])
ax.set(xlabel=r'rest frame wavelength [$\AA$]',
       title='Host + SN IIP')

axes[1,2].axis('off');

# %% [markdown]
# Hay muchas posibilidades entre las que le estamos pidiendo a la red que busque. Para facilitar las cosas, estos espectros se han _precondicionado_. Para lograr esto, hemos: eliminado el efecto del corrimiento al rojo del espectro observado;
# promediado en los intervalos (bins) vecinos, como anteriormente; renormalizado los flujos para que se encuentren entre [0, 1]; por lo tanto, ignoramos el brillo de las supernovas al determinar su tipo.

# %% [markdown]
# ## Creando un cerebro artificial para encontrar las bestias astronómicas más temperamentales

# %% [markdown]
# Primero crearemos nuestro cerebro artificial y luego diseñaremos desafíos que pueda intentar repetidamente y _aprender_. Si usamos todos nuestros datos para crear los desafíos, entonces no tenemos datos externos para probar qué tan bien está funcionando la red; este sería un ejemplo clásico de [sobreajuste](https://es.wikipedia.org/wiki/Sobreajuste).

# %% [markdown]
# Para evitar esto, dividiremos nuestros datos en conjuntos de *entrenamiento* (train) y *validación* (test). Finalmente, para ser amigable con la computadora, asignaremos _etiquetas enteras_ simples a los tipos que esperamos que la red pueda adivinar: (host, Ia, Ib, Ic, IIp) = (0,1,2,3,4) respectivamente.

# %%
# Divide los datos en variables x y y, donde x = espectros y y = nuestras etiquetas.
nbins = len(wave)

x = np.concatenate([host_fluxes, 
                    snia_fluxes,
                    snib_fluxes,
                    snic_fluxes,
                    snii_fluxes
                   ]).reshape(-1, nbins, 1)

# %%
y = to_categorical(
        np.concatenate([np.full(len(host_fluxes), 0), 
                        np.full(len(snia_fluxes), 1),
                        np.full(len(snib_fluxes), 2),
                        np.full(len(snic_fluxes), 3),
                        np.full(len(snii_fluxes), 4)
                       ]))

# %%
x.shape, y.shape
# Out:
# ((752, 150, 1), (752, 5))

# %%
# Dividiendo entre *entrenamiento* (train) y *validación* (test).
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.333)

# %% [markdown]
# ### La red
#
# Inicializaremos una red con un potencial limitado por tres capas convolucionales. Podría tener menos o más, según lo determinado por los pros y contras anteriores. También vamos a optimizar la red en función de su _exactitud_, una métrica que maximiza el número de predicciones de la red que coinciden con la verdad. También podríamos entrenar en otras métricas como _precision_, que minimiza la cantidad de predicciones falsas; parece que debería ser lo mismo, pero [no](https://es.wikipedia.org/wiki/Precisi%C3%B3n_y_exhaustividad).

# %%
def network(input_shape, ncat, learning_rate=0.0005, reg=0.003, dropout=0.7, seed=None):
    """Definimos la estructura de la red convolucional.
    
    Párametros
    ----------
    input_shape : int
        Forma del espectro de entrada.
    ncat : int
        Numero de categorias o clases.
    learning_rate : float
        Tasa de Aprendizaje.
    reg : float
        Factor de Regularización.
    dropout : float
        Factor de perdida.
    seed : int
        Semilla de inicialización
    
    Retorno
    -------
    modelo : tensorflow.keras.Model
        Una instancia modelo de la red.
    """
    X_input = Input(input_shape, name='Input_Spec')

    # Primera capa convolucional
    with backend.name_scope('Conv_1'):
        X = Conv1D(filters=8, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X_input)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size= 2)(X)

    # Segunda capa convolucional
    with backend.name_scope('Conv_2'):
        X = Conv1D(filters=16, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Tercera capa convolucional
    with backend.name_scope('Conv_3'):
        X = Conv1D(filters=32, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Capa aplanada completamente conectada
    with backend.name_scope('Dense_Layer'):
        X = Flatten()(X)
        X = Dense(256, kernel_regularizer=regularizers.l2(reg),
                  activation='relu')(X)
        X = Dropout(rate=dropout, seed=seed)(X)
    
    # Capa de salida con activación sigmoide
    with backend.name_scope('Output_Layer'):
        X = Dense(ncat, kernel_regularizer=regularizers.l2(reg),
              activation='sigmoid',name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='SNnet')
    
    # Configura el optimizador, la función de pérdida y las métricas de optimización.
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
# Definiremos la red aquí.
# La forma de entrada tendrá nbins = 150 bins de longitud de onda.
# El número de categorías está definido por la forma de nuestro vector y.
# Deberíamos tener cinco categorías (hosts, SN Ia, Ib, Ic y IIP).

cnn_model = network((nbins, 1), ncat=y.shape[1])
# Out:
# C:\Users\tu_rk\miniconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
cnn_model.summary()
# Out:
# Model: "SNnet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Spec (InputLayer)      [(None, 150, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 150, 8)            48
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 8)            32
# _________________________________________________________________
# activation (Activation)      (None, 150, 8)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 75, 8)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 75, 16)            656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 16)            64
# _________________________________________________________________
# activation_1 (Activation)    (None, 75, 16)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 37, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 37, 32)            2592
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 37, 32)            128
# _________________________________________________________________
# activation_2 (Activation)    (None, 37, 32)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 18, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               147712
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output_Classes (Dense)       (None, 5)                 1285
# =================================================================
# Total params: 152,517
# Trainable params: 152,405
# Non-trainable params: 112
# _________________________________________________________________

# %% [markdown]
# Considera esto por un minuto. En total, hay 152,405 valores distintos que se pueden entrenar en esta red. Eso es un poco menos que los ~10 mil millones en el tu cerebro, ¡pero aún es mucho! Esto significa que existe un potencial considerable para que la red obtenga muy buenos espectros distintivos de candidatos a supernovas, pero que se necesitará mucho aprendizaje para obtener resultados sensibles.

# %% [markdown]
# ### Mantenerse en pie por sí mismo

# %% [markdown]
# Ahora, deja que suceda la magia. Dejaremos que la red aborde los desafíos y diseñe sus pesos, o neuronas, para maximizar la satisfacción o su capacidad para tener éxito.

# %%
history = cnn_model.fit(x_train, y_train, batch_size=50, epochs=125, validation_data=(x_test, y_test), shuffle=True)
# Out:
# Epoch 1/125
# 11/11 [==============================] - 9s 601ms/step - loss: 3.3594 - accuracy: 0.2295 - val_loss: 2.7744 - val_accuracy: 0.2869
# Epoch 2/125
# 11/11 [==============================] - 5s 480ms/step - loss: 2.8267 - accuracy: 0.3493 - val_loss: 2.7571 - val_accuracy: 0.1793
# Epoch 3/125
# 11/11 [==============================] - 5s 500ms/step - loss: 2.6607 - accuracy: 0.4012 - val_loss: 2.7451 - val_accuracy: 0.1793
# Epoch 4/125
# 11/11 [==============================] - 5s 479ms/step - loss: 2.5106 - accuracy: 0.3892 - val_loss: 2.7365 - val_accuracy: 0.1793
# Epoch 5/125
# 11/11 [==============================] - 5s 480ms/step - loss: 2.4352 - accuracy: 0.4750 - val_loss: 2.7292 - val_accuracy: 0.1793
# Epoch 6/125
# 11/11 [==============================] - 5s 431ms/step - loss: 2.3813 - accuracy: 0.4671 - val_loss: 2.7219 - val_accuracy: 0.1793
# Epoch 7/125
# 11/11 [==============================] - 5s 519ms/step - loss: 2.3295 - accuracy: 0.4691 - val_loss: 2.7272 - val_accuracy: 0.1793
# Epoch 8/125
# 11/11 [==============================] - 7s 631ms/step - loss: 2.2302 - accuracy: 0.5369 - val_loss: 2.7517 - val_accuracy: 0.1793
# Epoch 9/125
# 11/11 [==============================] - 6s 560ms/step - loss: 2.2355 - accuracy: 0.5449 - val_loss: 2.7281 - val_accuracy: 0.1793
# Epoch 10/125
# 11/11 [==============================] - 6s 537ms/step - loss: 2.2178 - accuracy: 0.5269 - val_loss: 2.7221 - val_accuracy: 0.1793
# Epoch 11/125
# 11/11 [==============================] - 6s 582ms/step - loss: 2.1625 - accuracy: 0.5329 - val_loss: 2.7677 - val_accuracy: 0.1793
# Epoch 12/125
# 11/11 [==============================] - 6s 569ms/step - loss: 2.1756 - accuracy: 0.5449 - val_loss: 2.6896 - val_accuracy: 0.1793
# Epoch 13/125
# 11/11 [==============================] - 7s 641ms/step - loss: 2.1406 - accuracy: 0.5429 - val_loss: 2.6880 - val_accuracy: 0.1793
# Epoch 14/125
# 11/11 [==============================] - 7s 660ms/step - loss: 2.1210 - accuracy: 0.5409 - val_loss: 2.7271 - val_accuracy: 0.1793
# Epoch 15/125
# 11/11 [==============================] - 7s 630ms/step - loss: 2.0338 - accuracy: 0.5848 - val_loss: 2.7451 - val_accuracy: 0.1793
# Epoch 16/125
# 11/11 [==============================] - 6s 582ms/step - loss: 1.9819 - accuracy: 0.6188 - val_loss: 2.7288 - val_accuracy: 0.1833
# Epoch 17/125
# 11/11 [==============================] - 5s 500ms/step - loss: 1.9719 - accuracy: 0.6347 - val_loss: 2.7203 - val_accuracy: 0.1992
# Epoch 18/125
# 11/11 [==============================] - 5s 489ms/step - loss: 1.8918 - accuracy: 0.6248 - val_loss: 2.7143 - val_accuracy: 0.2510
# Epoch 19/125
# 11/11 [==============================] - 6s 540ms/step - loss: 1.9069 - accuracy: 0.6248 - val_loss: 2.7534 - val_accuracy: 0.2590
# Epoch 20/125
# 11/11 [==============================] - 6s 530ms/step - loss: 1.9399 - accuracy: 0.5948 - val_loss: 2.6836 - val_accuracy: 0.3068
# Epoch 21/125
# 11/11 [==============================] - 6s 560ms/step - loss: 1.8376 - accuracy: 0.6527 - val_loss: 2.6792 - val_accuracy: 0.3108
# Epoch 22/125
# 11/11 [==============================] - 5s 491ms/step - loss: 1.8259 - accuracy: 0.6387 - val_loss: 2.7234 - val_accuracy: 0.2669
# Epoch 23/125
# 11/11 [==============================] - 6s 531ms/step - loss: 1.8021 - accuracy: 0.6447 - val_loss: 2.7077 - val_accuracy: 0.2988
# Epoch 24/125
# 11/11 [==============================] - 7s 680ms/step - loss: 1.8139 - accuracy: 0.6387 - val_loss: 2.6177 - val_accuracy: 0.3147
# Epoch 25/125
# 11/11 [==============================] - 5s 510ms/step - loss: 1.8039 - accuracy: 0.6467 - val_loss: 2.6327 - val_accuracy: 0.3426
# Epoch 26/125
# 11/11 [==============================] - 5s 490ms/step - loss: 1.7656 - accuracy: 0.6667 - val_loss: 2.5980 - val_accuracy: 0.3466
# Epoch 27/125
# 11/11 [==============================] - 6s 579ms/step - loss: 1.7594 - accuracy: 0.6547 - val_loss: 2.6184 - val_accuracy: 0.3586
# Epoch 28/125
# 11/11 [==============================] - 6s 491ms/step - loss: 1.7124 - accuracy: 0.6667 - val_loss: 2.4439 - val_accuracy: 0.4024
# Epoch 29/125
# 11/11 [==============================] - 6s 560ms/step - loss: 1.7989 - accuracy: 0.6168 - val_loss: 2.4761 - val_accuracy: 0.3625
# Epoch 30/125
# 11/11 [==============================] - 6s 569ms/step - loss: 1.7121 - accuracy: 0.7086 - val_loss: 2.4624 - val_accuracy: 0.3865
# Epoch 31/125
# 11/11 [==============================] - 5s 450ms/step - loss: 1.7067 - accuracy: 0.6886 - val_loss: 2.3950 - val_accuracy: 0.4024
# Epoch 32/125
# 11/11 [==============================] - 5s 480ms/step - loss: 1.6457 - accuracy: 0.6986 - val_loss: 2.3899 - val_accuracy: 0.3904
# Epoch 33/125
# 11/11 [==============================] - 5s 481ms/step - loss: 1.6690 - accuracy: 0.6806 - val_loss: 2.3553 - val_accuracy: 0.3745
# Epoch 34/125
# 11/11 [==============================] - 4s 350ms/step - loss: 1.6328 - accuracy: 0.6846 - val_loss: 2.3259 - val_accuracy: 0.3865
# Epoch 35/125
# 11/11 [==============================] - 4s 409ms/step - loss: 1.6427 - accuracy: 0.6786 - val_loss: 2.2856 - val_accuracy: 0.4462
# Epoch 36/125
# 11/11 [==============================] - 4s 379ms/step - loss: 1.5908 - accuracy: 0.7146 - val_loss: 2.1454 - val_accuracy: 0.4582
# Epoch 37/125
# 11/11 [==============================] - 3s 300ms/step - loss: 1.5637 - accuracy: 0.7206 - val_loss: 2.1569 - val_accuracy: 0.4502
# Epoch 38/125
# 11/11 [==============================] - 3s 279ms/step - loss: 1.5145 - accuracy: 0.7625 - val_loss: 2.0917 - val_accuracy: 0.4821
# Epoch 39/125
# 11/11 [==============================] - 3s 323ms/step - loss: 1.5037 - accuracy: 0.7425 - val_loss: 2.0763 - val_accuracy: 0.4741
# Epoch 40/125
# 11/11 [==============================] - 5s 499ms/step - loss: 1.4815 - accuracy: 0.7445 - val_loss: 2.0429 - val_accuracy: 0.4861
# Epoch 41/125
# 11/11 [==============================] - 5s 429ms/step - loss: 1.4526 - accuracy: 0.7685 - val_loss: 1.9843 - val_accuracy: 0.5139
# Epoch 42/125
# 11/11 [==============================] - 5s 409ms/step - loss: 1.4680 - accuracy: 0.7565 - val_loss: 1.9427 - val_accuracy: 0.5299
# Epoch 43/125
# 11/11 [==============================] - 6s 560ms/step - loss: 1.4215 - accuracy: 0.7625 - val_loss: 1.9284 - val_accuracy: 0.5378
# Epoch 44/125
# 11/11 [==============================] - 5s 491ms/step - loss: 1.3986 - accuracy: 0.7685 - val_loss: 1.8609 - val_accuracy: 0.6056
# Epoch 45/125
# 11/11 [==============================] - 6s 491ms/step - loss: 1.4358 - accuracy: 0.7605 - val_loss: 1.8657 - val_accuracy: 0.5896
# Epoch 46/125
# 11/11 [==============================] - 5s 431ms/step - loss: 1.4290 - accuracy: 0.7745 - val_loss: 1.8866 - val_accuracy: 0.5378
# Epoch 47/125
# 11/11 [==============================] - 5s 470ms/step - loss: 1.3969 - accuracy: 0.7964 - val_loss: 1.8111 - val_accuracy: 0.6175
# Epoch 48/125
# 11/11 [==============================] - 5s 480ms/step - loss: 1.4175 - accuracy: 0.7645 - val_loss: 1.8065 - val_accuracy: 0.6016
# Epoch 49/125
# 11/11 [==============================] - 6s 531ms/step - loss: 1.3787 - accuracy: 0.7804 - val_loss: 1.7789 - val_accuracy: 0.6215
# Epoch 50/125
# 11/11 [==============================] - 5s 460ms/step - loss: 1.3754 - accuracy: 0.7764 - val_loss: 1.7478 - val_accuracy: 0.6414
# Epoch 51/125
# 11/11 [==============================] - 6s 600ms/step - loss: 1.3423 - accuracy: 0.7804 - val_loss: 1.7219 - val_accuracy: 0.6494
# Epoch 52/125
# 11/11 [==============================] - 6s 521ms/step - loss: 1.3041 - accuracy: 0.8204 - val_loss: 1.7320 - val_accuracy: 0.6534
# Epoch 53/125
# 11/11 [==============================] - 6s 531ms/step - loss: 1.3042 - accuracy: 0.8024 - val_loss: 1.6954 - val_accuracy: 0.6574
# Epoch 54/125
# 11/11 [==============================] - 5s 468ms/step - loss: 1.3266 - accuracy: 0.7924 - val_loss: 1.7073 - val_accuracy: 0.6414
# Epoch 55/125
# 11/11 [==============================] - 6s 521ms/step - loss: 1.2776 - accuracy: 0.8164 - val_loss: 1.6636 - val_accuracy: 0.6773
# Epoch 56/125
# 11/11 [==============================] - 5s 421ms/step - loss: 1.4788 - accuracy: 0.7345 - val_loss: 1.7026 - val_accuracy: 0.6295
# Epoch 57/125
# 11/11 [==============================] - 6s 538ms/step - loss: 1.4007 - accuracy: 0.7485 - val_loss: 1.7516 - val_accuracy: 0.6295
# Epoch 58/125
# 11/11 [==============================] - 5s 449ms/step - loss: 1.4256 - accuracy: 0.7345 - val_loss: 1.7222 - val_accuracy: 0.6175
# Epoch 59/125
# 11/11 [==============================] - 4s 318ms/step - loss: 1.3658 - accuracy: 0.7725 - val_loss: 1.6831 - val_accuracy: 0.6653
# Epoch 60/125
# 11/11 [==============================] - 5s 430ms/step - loss: 1.2762 - accuracy: 0.8124 - val_loss: 1.6589 - val_accuracy: 0.6534
# Epoch 61/125
# 11/11 [==============================] - 4s 361ms/step - loss: 1.2710 - accuracy: 0.8044 - val_loss: 1.6396 - val_accuracy: 0.6653
# Epoch 62/125
# 11/11 [==============================] - 5s 401ms/step - loss: 1.2597 - accuracy: 0.7984 - val_loss: 1.6304 - val_accuracy: 0.6653
# Epoch 63/125
# 11/11 [==============================] - 4s 382ms/step - loss: 1.2716 - accuracy: 0.8084 - val_loss: 1.6401 - val_accuracy: 0.6733
# Epoch 64/125
# 11/11 [==============================] - 4s 389ms/step - loss: 1.2161 - accuracy: 0.8423 - val_loss: 1.6794 - val_accuracy: 0.6733
# Epoch 65/125
# 11/11 [==============================] - 6s 551ms/step - loss: 1.2917 - accuracy: 0.7944 - val_loss: 1.7990 - val_accuracy: 0.6335
# Epoch 66/125
# 11/11 [==============================] - 5s 481ms/step - loss: 1.2946 - accuracy: 0.8084 - val_loss: 1.6712 - val_accuracy: 0.6574
# Epoch 67/125
# 11/11 [==============================] - 6s 521ms/step - loss: 1.2944 - accuracy: 0.7884 - val_loss: 1.6416 - val_accuracy: 0.6733
# Epoch 68/125
# 11/11 [==============================] - 5s 481ms/step - loss: 1.2387 - accuracy: 0.7924 - val_loss: 1.6889 - val_accuracy: 0.6574
# Epoch 69/125
# 11/11 [==============================] - 4s 380ms/step - loss: 1.2615 - accuracy: 0.7904 - val_loss: 1.6699 - val_accuracy: 0.6494
# Epoch 70/125
# 11/11 [==============================] - 5s 500ms/step - loss: 1.2514 - accuracy: 0.7884 - val_loss: 1.6103 - val_accuracy: 0.6853
# Epoch 71/125
# 11/11 [==============================] - 5s 518ms/step - loss: 1.2031 - accuracy: 0.8343 - val_loss: 1.6267 - val_accuracy: 0.6614
# Epoch 72/125
# 11/11 [==============================] - 6s 541ms/step - loss: 1.2045 - accuracy: 0.8244 - val_loss: 1.6359 - val_accuracy: 0.6574
# Epoch 73/125
# 11/11 [==============================] - 5s 420ms/step - loss: 1.1543 - accuracy: 0.8523 - val_loss: 1.6273 - val_accuracy: 0.6813
# Epoch 74/125
# 11/11 [==============================] - 5s 419ms/step - loss: 1.1790 - accuracy: 0.8283 - val_loss: 1.6344 - val_accuracy: 0.6653
# Epoch 75/125
# 11/11 [==============================] - 5s 450ms/step - loss: 1.2025 - accuracy: 0.8323 - val_loss: 1.6373 - val_accuracy: 0.6653
# Epoch 76/125
# 11/11 [==============================] - 4s 390ms/step - loss: 1.1272 - accuracy: 0.8663 - val_loss: 1.6264 - val_accuracy: 0.6653
# Epoch 77/125
# 11/11 [==============================] - 4s 411ms/step - loss: 1.1151 - accuracy: 0.8743 - val_loss: 1.5997 - val_accuracy: 0.6733
# Epoch 78/125
# 11/11 [==============================] - 5s 469ms/step - loss: 1.1007 - accuracy: 0.8663 - val_loss: 1.5942 - val_accuracy: 0.6653
# Epoch 79/125
# 11/11 [==============================] - 4s 400ms/step - loss: 1.1459 - accuracy: 0.8303 - val_loss: 1.6734 - val_accuracy: 0.6534
# Epoch 80/125
# 11/11 [==============================] - 4s 330ms/step - loss: 1.1915 - accuracy: 0.8263 - val_loss: 1.6229 - val_accuracy: 0.6534
# Epoch 81/125
# 11/11 [==============================] - 7s 582ms/step - loss: 1.2306 - accuracy: 0.8064 - val_loss: 1.6238 - val_accuracy: 0.6693
# Epoch 82/125
# 11/11 [==============================] - 4s 380ms/step - loss: 1.1937 - accuracy: 0.8224 - val_loss: 1.6663 - val_accuracy: 0.6693
# Epoch 83/125
# 11/11 [==============================] - 5s 521ms/step - loss: 1.2492 - accuracy: 0.7804 - val_loss: 1.6845 - val_accuracy: 0.6295
# Epoch 84/125
# 11/11 [==============================] - 7s 589ms/step - loss: 1.1734 - accuracy: 0.8283 - val_loss: 1.6155 - val_accuracy: 0.6295
# Epoch 85/125
# 11/11 [==============================] - 6s 509ms/step - loss: 1.1719 - accuracy: 0.8343 - val_loss: 1.6619 - val_accuracy: 0.6494
# Epoch 86/125
# 11/11 [==============================] - 6s 512ms/step - loss: 1.1299 - accuracy: 0.8463 - val_loss: 1.6600 - val_accuracy: 0.6693
# Epoch 87/125
# 11/11 [==============================] - 5s 500ms/step - loss: 1.0743 - accuracy: 0.8723 - val_loss: 1.5947 - val_accuracy: 0.6773
# Epoch 88/125
# 11/11 [==============================] - 4s 380ms/step - loss: 1.0504 - accuracy: 0.8703 - val_loss: 1.5797 - val_accuracy: 0.6892
# Epoch 89/125
# 11/11 [==============================] - 5s 470ms/step - loss: 1.0448 - accuracy: 0.8922 - val_loss: 1.5967 - val_accuracy: 0.6892
# Epoch 90/125
# 11/11 [==============================] - 5s 429ms/step - loss: 1.0473 - accuracy: 0.8862 - val_loss: 1.5984 - val_accuracy: 0.6653
# Epoch 91/125
# 11/11 [==============================] - 6s 480ms/step - loss: 1.0176 - accuracy: 0.9122 - val_loss: 1.5856 - val_accuracy: 0.6813
# Epoch 92/125
# 11/11 [==============================] - 6s 511ms/step - loss: 1.0248 - accuracy: 0.8882 - val_loss: 1.5716 - val_accuracy: 0.6733
# Epoch 93/125
# 11/11 [==============================] - 8s 771ms/step - loss: 1.0355 - accuracy: 0.8743 - val_loss: 1.6142 - val_accuracy: 0.6653
# Epoch 94/125
# 11/11 [==============================] - 6s 560ms/step - loss: 1.0766 - accuracy: 0.8543 - val_loss: 1.6345 - val_accuracy: 0.6454
# Epoch 95/125
# 11/11 [==============================] - 5s 450ms/step - loss: 1.0345 - accuracy: 0.8822 - val_loss: 1.5766 - val_accuracy: 0.6733
# Epoch 96/125
# 11/11 [==============================] - 6s 531ms/step - loss: 1.0335 - accuracy: 0.8902 - val_loss: 1.5960 - val_accuracy: 0.6574
# Epoch 97/125
# 11/11 [==============================] - 6s 549ms/step - loss: 1.0707 - accuracy: 0.8703 - val_loss: 1.6589 - val_accuracy: 0.6414
# Epoch 98/125
# 11/11 [==============================] - 6s 560ms/step - loss: 1.1206 - accuracy: 0.8383 - val_loss: 1.6636 - val_accuracy: 0.6494
# Epoch 99/125
# 11/11 [==============================] - 7s 680ms/step - loss: 1.0518 - accuracy: 0.8762 - val_loss: 1.6616 - val_accuracy: 0.6693
# Epoch 100/125
# 11/11 [==============================] - 5s 481ms/step - loss: 1.0358 - accuracy: 0.8743 - val_loss: 1.6133 - val_accuracy: 0.6534
# Epoch 101/125
# 11/11 [==============================] - 6s 501ms/step - loss: 0.9926 - accuracy: 0.8802 - val_loss: 1.6275 - val_accuracy: 0.6534
# Epoch 102/125
# 11/11 [==============================] - 5s 439ms/step - loss: 0.9906 - accuracy: 0.8922 - val_loss: 1.5738 - val_accuracy: 0.6773
# Epoch 103/125
# 11/11 [==============================] - 5s 500ms/step - loss: 0.9918 - accuracy: 0.8922 - val_loss: 1.5696 - val_accuracy: 0.6614
# Epoch 104/125
# 11/11 [==============================] - 8s 680ms/step - loss: 1.0362 - accuracy: 0.8703 - val_loss: 1.6708 - val_accuracy: 0.6215
# Epoch 105/125
# 11/11 [==============================] - 5s 500ms/step - loss: 1.0398 - accuracy: 0.8523 - val_loss: 1.6016 - val_accuracy: 0.6574
# Epoch 106/125
# 11/11 [==============================] - 5s 440ms/step - loss: 1.1055 - accuracy: 0.8303 - val_loss: 1.5655 - val_accuracy: 0.6614
# Epoch 107/125
# 11/11 [==============================] - 6s 501ms/step - loss: 1.0601 - accuracy: 0.8383 - val_loss: 1.6157 - val_accuracy: 0.6614
# Epoch 108/125
# 11/11 [==============================] - 6s 579ms/step - loss: 1.1219 - accuracy: 0.8363 - val_loss: 1.5812 - val_accuracy: 0.6414
# Epoch 109/125
# 11/11 [==============================] - 4s 381ms/step - loss: 1.0855 - accuracy: 0.8403 - val_loss: 1.6785 - val_accuracy: 0.6534
# Epoch 110/125
# 11/11 [==============================] - 5s 470ms/step - loss: 1.1115 - accuracy: 0.8224 - val_loss: 1.6654 - val_accuracy: 0.6454
# Epoch 111/125
# 11/11 [==============================] - 5s 480ms/step - loss: 1.0505 - accuracy: 0.8303 - val_loss: 1.6373 - val_accuracy: 0.6335
# Epoch 112/125
# 11/11 [==============================] - 5s 470ms/step - loss: 1.0537 - accuracy: 0.8583 - val_loss: 1.6190 - val_accuracy: 0.6614
# Epoch 113/125
# 11/11 [==============================] - 6s 501ms/step - loss: 1.0209 - accuracy: 0.8643 - val_loss: 1.6051 - val_accuracy: 0.6454
# Epoch 114/125
# 11/11 [==============================] - 6s 560ms/step - loss: 0.9550 - accuracy: 0.9082 - val_loss: 1.5925 - val_accuracy: 0.6653
# Epoch 115/125
# 11/11 [==============================] - 7s 649ms/step - loss: 1.0018 - accuracy: 0.8743 - val_loss: 1.6154 - val_accuracy: 0.6375
# Epoch 116/125
# 11/11 [==============================] - 7s 669ms/step - loss: 1.0198 - accuracy: 0.8583 - val_loss: 1.5975 - val_accuracy: 0.6335
# Epoch 117/125
# 11/11 [==============================] - 7s 629ms/step - loss: 1.0063 - accuracy: 0.8802 - val_loss: 1.6725 - val_accuracy: 0.6335
# Epoch 118/125
# 11/11 [==============================] - 7s 642ms/step - loss: 1.0821 - accuracy: 0.8463 - val_loss: 1.8651 - val_accuracy: 0.6255
# Epoch 119/125
# 11/11 [==============================] - 5s 490ms/step - loss: 1.0284 - accuracy: 0.8403 - val_loss: 1.6420 - val_accuracy: 0.6494
# Epoch 120/125
# 11/11 [==============================] - 6s 550ms/step - loss: 1.0145 - accuracy: 0.8743 - val_loss: 1.6118 - val_accuracy: 0.6414
# Epoch 121/125
# 11/11 [==============================] - 8s 670ms/step - loss: 0.9705 - accuracy: 0.8942 - val_loss: 1.6350 - val_accuracy: 0.6614
# Epoch 122/125
# 11/11 [==============================] - 6s 548ms/step - loss: 0.9230 - accuracy: 0.9162 - val_loss: 1.6176 - val_accuracy: 0.6614
# Epoch 123/125
# 11/11 [==============================] - 6s 460ms/step - loss: 0.9262 - accuracy: 0.9002 - val_loss: 1.5826 - val_accuracy: 0.6574
# Epoch 124/125
# 11/11 [==============================] - 5s 440ms/step - loss: 0.9198 - accuracy: 0.9182 - val_loss: 1.6099 - val_accuracy: 0.6335
# Epoch 125/125
# 11/11 [==============================] - 6s 570ms/step - loss: 0.9335 - accuracy: 0.9102 - val_loss: 1.5745 - val_accuracy: 0.6653

# %% [markdown]
# ### ¿Pro o no pro?
#
# Cada vez que la red intenta aprender, el desafío se conoce como una "época". A medida que aprende, deberíamos preocuparnos por la pérdida: una medida de qué tan mal la red está identificando nuestros espectros, que queremos minimizar. Por su parte, la precisión mide qué tan bien lo hace la red en la identificación de las cinco clases diferentes simuladas, siendo esto lo que queremos maximizar.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5), sharex=True)

nepoch = len(history.history['loss'])
epochs = np.arange(1, nepoch+1)

ax = axes[0]
ax.plot(epochs, history.history['accuracy'], label='acc')
ax.plot(epochs, history.history['val_accuracy'], label='val_acc')
ax.set(xlabel='Época de entrenamiento',
       ylabel='Precisión',
       xlim=(0, nepoch),
       ylim=(0.,1.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

ax = axes[1]
ax.plot(epochs, history.history['loss'], label='loss')
ax.plot(epochs, history.history['val_loss'], label='val_loss')
ax.set(xlabel='Época de entrenamiento',
       ylabel='Pérdida',
       xlim=(0, nepoch),
#        ylim=(0.,2.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

fig.tight_layout();

# %% [markdown]
# Podemos ver que la red aprendió inicialmente muy rápido, pero la mejora se ralentizó alrededor de 50 épocas más o menos. En este punto, la precisión alcanzada fue de alrededor del 70%, ¡así que no está mal!

# %% [markdown]
# ### Matriz de confusión
#
# En este tipo de clasificación, otra forma de medir el éxito es mediante la _matriz de confusión_,

# %%
# Vamos a utilizar la muestra de prueba para probar las predicciones de nuestra
# CNN entrenada ahora que ha "aprendido" a distinguir los diferentes tipos de
# supernovas. Esto no es ideal ... deberíamos tener una tercer
# muestra independiente de las muestras de entrenamiento y prueba.
y_pred = cnn_model.predict(x_test)

# En el clasificador de clases múltiples, evalue el máximo de
# coincidencias en la matriz de salida de valores.
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
cmnorm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
fig, ax = plt.subplots(1,1, figsize=(8,7))

im = ax.imshow(cmnorm, cmap='Blues', vmin=0, vmax=1)
cb = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cb.set_label('Fracción Correcta')

labels = ['Hosts', 'SN Ia', 'SN Ib', 'SN Ic', 'SN IIP']

ax.set(aspect='equal',
       xlabel='Clase Predicha',
       xticks=np.arange(cm.shape[1]),
       xticklabels=labels,
       ylabel='Clase Verdadera',
       yticks=np.arange(cm.shape[1]),
       yticklabels=labels)

thresh = 0.5*cm.max()
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, '{:.3f}\n({:d})'.format(cmnorm[i,j], cm[i,j]),
                ha='center', va='center',
                color='black' if cm[i,j] < thresh else 'white')

fig.tight_layout()

# %% [markdown]
# Si la CNN es perfecta para clasificar todas las categorías, entonces la entrada 'Etiqueta verdadera' y la salida de 'Etiqueta predicha' de la red coincidirían siempre. En este caso, solo los cuadrados diagonales aparecerían rellenos en la matriz; el resto estarían en blanco.
#
# En nuestro caso, vemos que la CNN es realmente buena para clasificar el tipo Ia; promedio en la clasificación de tipo IIP; y mediocre en la clasificación de Ib y Ic supernvoae. Parece estar mezclando el tipo Ib y el Ic, y afirma incorrectamente que el 10% de las galaxias anfitrionas contienen en realidad una supernova de tipo Ib. ¡Ups!

# %% [markdown]
# Finalmente, es notable que hemos completado el círculo, por supuesto, ya que el silicio fundamental para los transitores en el que se realizará este cálculo, se originó en las mismas supernovas que estamos buscando.

# %% [markdown]
# ## ¿Puedes hacerlo mejor?

# %% [markdown]
# Una de las cosas fascinantes del aprendizaje automático es que se trata de un número ilimitado de cosas que se pueden modificar y que podrían mejorar el rendimiento. El arte es saber qué cosas pueden mejorar las condiciones para un problema dado.

# %% [markdown]
# _Aumentar el tamaño del conjunto de entrenamiento_: podríamos creer que hemos proporcionado datos insuficientes para que la red aprenda. Tenemos más disponibles en el _conjunto de validación_ que podríamos agregar, pero ¿a qué costo? Si la red mejora, ¿es real o simplemente está sobreajustada? Sin embargo, puedes intentar cambiar a una 'división 80-20' de los datos.
#
# _Personalizar la tasa de aprendizaje y abandono_: la rapidez con la que la CNN reacciona a los nuevos datos está determinada por una _tasa de aprendizaje preestablecida_: hay un equilibrio que hay que mantener para resolver mejor los problemas nuevos, sin dejar de hacerlo bien en los viejos; Esto a menudo se conoce como "histéresis" dentro de la física, en analogía con efectos similares en el magnetismo. Puede intentar cambiar la tasa de aprendizaje en la $\tt{red}$ anterior.
#
#
# _Cambio de la 'arquitectura'_: hemos limitado la red a tres capas, podríamos agregar más o menos. ¿Encuentra alguna diferencia significativa?

# %% [markdown]
# ## Entonces, te gusta el aprendizaje automático ...
#
# Bueno, ¡estás muy bien preparado para los probables éxitos y desafíos del próximo siglo! Existe una gran cantidad de material, pero lo siguiente es muy recomendable: [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/), [3blue1brown: Neural Networks](https://youtu.be/aircAruvnKk) y [Aprendizaje profundo con Python](https://www.amazon.com/Deep-Learning-Python-Francois-Chollet/dp/1617294438).
#
# Realmente el aprendizaje automático tiene el potencial de cambiar todo, como se ha demostrado asombrosamente [recientemente](https://www.nature.com/articles/d41586-020-03348-4).
